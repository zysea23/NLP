# %% [markdown]
# # Named Entity Recognition with Bi-LSTM on CoNLL-2003 dataset

# %% [markdown]
# # 1. Data Loading

# %%
# %pip install seqeval

# Import necessary libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
import numpy as np
from sklearn.metrics import classification_report
from seqeval.metrics import f1_score, classification_report as seq_classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict, Counter
import pandas as pd
import os
from itertools import product
# Out:
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.14.0->seqeval) (2.4.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.14.0->seqeval) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.14.0->seqeval) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.14.0->seqeval) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.14.0->seqeval) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.14.0->seqeval) (2024.2.0)

# %%
# Load the CoNLL-2003 dataset
dataset = load_dataset("eriktks/conll2003", trust_remote_code=True)
print(dataset)
# Out:
# README.md:   0%|          | 0.00/12.3k [00:00<?, ?B/s]
# conll2003.py:   0%|          | 0.00/9.57k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/983k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 14041
#     })
#     validation: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3250
#     })
#     test: Dataset({
#         features: ['id', 'tokens', 'pos_tags', 'chunk_tags', 'ner_tags'],
#         num_rows: 3453
#     })
# })

# %%
# View the first training example
print(dataset['train'][0])
# Out:
# {'id': '0', 'tokens': ['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'], 'pos_tags': [22, 42, 16, 21, 35, 37, 16, 21, 7], 'chunk_tags': [11, 21, 11, 12, 21, 22, 11, 12, 0], 'ner_tags': [3, 0, 7, 0, 0, 0, 7, 0, 0]}

# %% [markdown]
# # 2. Vocabulary Building

# %%
# Build vocabulary based on frequency of words
counter = Counter()
for tokens in dataset['train']['tokens']:
    counter.update(tokens)

# Select the most common 30000 words **
vocab = ['<PAD>', '<UNK>'] + [word for word, freq in counter.most_common(30000)]

# Build word mappings
word2idx = {word: idx for idx, word in enumerate(vocab)}
idx2word = {idx: word for word, idx in word2idx.items()}

# %%
print('Vocabulary size:', len(vocab))
print('Most common 10 words:', vocab[:10])

print('First 5 words:', list(word2idx.items())[:5])
print('First 5 indices:', list(idx2word.items())[:5])
# Out:
# Vocabulary size: 23625
# Most common 10 words: ['<PAD>', '<UNK>', '.', ',', 'the', 'of', 'in', 'to', 'a', '(']
# First 5 words: [('<PAD>', 0), ('<UNK>', 1), ('.', 2), (',', 3), ('the', 4)]
# First 5 indices: [(0, '<PAD>'), (1, '<UNK>'), (2, '.'), (3, ','), (4, 'the')]

# %%
# Build tag mappings
ner_tags = dataset['train'].features['ner_tags'].feature.names  

tag2idx = {tag: idx for idx, tag in enumerate(ner_tags)}    #{'O': 0, 'B-PER': 1,..., 'I-MISC': 8}
# Add padding tag
tag2idx['<PAD>'] = len(tag2idx)         #{'O': 0, 'B-PER': 1,..., 'I-MISC': 8, '<PAD>': 9}

idx2tag = {idx: tag for tag, idx in tag2idx.items()}

# %%
print('NER tags:', ner_tags)
print('Tag to index:', tag2idx)
print('Index to tag:', idx2tag)
# Out:
# NER tags: ['O', 'B-PER', 'I-PER', 'B-ORG', 'I-ORG', 'B-LOC', 'I-LOC', 'B-MISC', 'I-MISC']
# Tag to index: {'O': 0, 'B-PER': 1, 'I-PER': 2, 'B-ORG': 3, 'I-ORG': 4, 'B-LOC': 5, 'I-LOC': 6, 'B-MISC': 7, 'I-MISC': 8, '<PAD>': 9}
# Index to tag: {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC', 9: '<PAD>'}

# %%
# Calculate the length of each sentence
sentence_lengths = [len(tokens) for tokens in dataset['train']['tokens']]

# Calculate the maximum length on 99.9%
MAX_LEN = int(np.percentile(sentence_lengths, 99.9))

print(f"Suggested max_len based on 99.9 percentile: {MAX_LEN}")
# Out:
# Suggested max_len based on 99.9 percentile: 55

# %% [markdown]
# # 3. Model Definition

# %%
# Define a custom Dataset class for NER
class NERDataset(Dataset):
    def __init__(self, tokens_list, tags_list, word2idx, tag2idx, max_len=128): 
        self.tokens_list = tokens_list
        self.tags_list = tags_list
        self.word2idx = word2idx
        self.tag2idx = tag2idx
        self.max_len = max_len

    def __len__(self):
        return len(self.tokens_list)

    def __getitem__(self, idx):
        tokens = self.tokens_list[idx]
        tags = self.tags_list[idx]

        # Convert tokens to indices
        token_ids = [self.word2idx.get(token, self.word2idx['<UNK>']) for token in tokens]
        # Convert tags to indices
        tag_ids = [tag for tag in tags] 

        # Truncate if longer than max_len
        if len(token_ids) > self.max_len:
            token_ids = token_ids[:self.max_len]
            tag_ids = tag_ids[:self.max_len]

        # Record original length to use in evaluation **
        length = len(token_ids)

        # Padding
        padding_length = self.max_len - length
        token_ids += [self.word2idx['<PAD>']] * padding_length
        tag_ids += [self.tag2idx['<PAD>']] * padding_length  # Pad tags with '<PAD>'


        return {
            'tokens': torch.tensor(token_ids, dtype=torch.long),
            'tags': torch.tensor(tag_ids, dtype=torch.long),
            'length': torch.tensor(length, dtype=torch.long)
        }

# %%
# Define BiLSTM model
class BiLSTM_NER(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, tagset_size, padding_idx=0, lstm_layers=1, dropout_rate=0.5): # Add lstm_layers and dropout_rate
        super(BiLSTM_NER, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=padding_idx)
        # modify the hidden_dim to hidden_dim // 2 to account for the bidirectional nature of the LSTM
        self.bilstm = nn.LSTM(embed_dim, hidden_dim // 2, num_layers=lstm_layers, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_dim, tagset_size)
        self.dropout = nn.Dropout(dropout_rate)
    
    def forward(self, x):
        embeds = self.embedding(x)
        embeds = self.dropout(embeds)
        lstm_out, _ = self.bilstm(embeds)
        lstm_out = self.dropout(lstm_out)
        logits = self.fc(lstm_out)
        return logits

# %%
class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        """Initialize early stopping parameters.
        Args:
            patience (int): Number of epochs with no improvement after which training will be stopped.
            min_delta (float): Minimum change in validation loss to qualify as an improvement.
        """
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0

    def step(self, val_loss):
        """Check if training should stop based on validation loss.
        Args:
            val_loss (float): Current validation loss.
        Returns:
            bool: True if training should stop, False otherwise.
        """
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
        return self.counter >= self.patience

# %% [markdown]
# # 4. Model Building

# %% [markdown]
# ## - Hyperparameter

# %%
# Hyperparameter to fine-tune


embed_dims = [100, 200]
hidden_dims = [256,512]
lstm_layers = [1,2,3]
dropout_rates = [0.3, 0.5]

BATCH_SIZE = 64
# EMBED_DIM = 100
# HIDDEN_DIM = 512  
# LSTM_LAYERS = 2
# DROPOUT_RATE = 0.3

# %%
MAX_LEN = 55
VOCAB_SIZE = len(word2idx)
TAGSET_SIZE = len(tag2idx)

# %%
# Create Dataset instances

train_dataset = NERDataset(
    tokens_list=dataset['train']['tokens'],
    tags_list=dataset['train']['ner_tags'],
    word2idx=word2idx,
    tag2idx=tag2idx,
    max_len=MAX_LEN
)

valid_dataset = NERDataset(
    tokens_list=dataset['validation']['tokens'],
    tags_list=dataset['validation']['ner_tags'],
    word2idx=word2idx,
    tag2idx=tag2idx,
    max_len=MAX_LEN
)

test_dataset = NERDataset(
    tokens_list=dataset['test']['tokens'],
    tags_list=dataset['test']['ner_tags'],
    word2idx=word2idx,
    tag2idx=tag2idx,
    max_len=MAX_LEN
)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# # Instantiate the model
# model = BiLSTM_NER(
#     vocab_size=VOCAB_SIZE,
#     embed_dim=EMBED_DIM,
#     hidden_dim=HIDDEN_DIM,
#     tagset_size=TAGSET_SIZE,
#     padding_idx=word2idx['<PAD>'],
#     lstm_layers=LSTM_LAYERS,       
#     dropout_rate=DROPOUT_RATE     
# )

# %%
# Move the model to GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)
# model.to(device)
# Out:
# Using device: cuda

# %% [markdown]
# # 5. Model Training

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss(ignore_index=tag2idx['<PAD>'])

# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  
# optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-5)  

# #ReduceLROnPlateau
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

# %%
# Define training function
def train(model, dataloader, optimizer, criterion, device):
    model.train()
    epoch_loss = 0

    for batch in dataloader:
        tokens = batch['tokens'].to(device)
        tags = batch['tags'].to(device)

        optimizer.zero_grad()
        outputs = model(tokens)  # [batch_size, seq_len, tagset_size]

        # Reshape for loss computation
        outputs = outputs.view(-1, TAGSET_SIZE)  # [batch_size * seq_len, tagset_size]
        tags = tags.view(-1)  # [batch_size * seq_len]

        loss = criterion(outputs, tags)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()

    return epoch_loss / len(dataloader)

# %%
# Define evaluation function
def evaluate(model, dataloader, criterion, device):
    model.eval()
    epoch_loss = 0
    all_preds = []
    all_tags = []

    with torch.no_grad():
        for batch in dataloader:
            tokens = batch['tokens'].to(device)
            tags = batch['tags'].to(device)

            outputs = model(tokens)  # [batch_size, seq_len, tagset_size]

            # Reshape for loss computation
            outputs = outputs.view(-1, TAGSET_SIZE)  # [batch_size * seq_len, tagset_size]
            tags = tags.view(-1)  # [batch_size * seq_len]

            loss = criterion(outputs, tags)
            epoch_loss += loss.item()

            # Get predictions
            _, preds = torch.max(outputs, dim=1)  # [batch_size * seq_len]

            # Convert to numpy arrays
            preds = preds.cpu().numpy()
            tags = tags.cpu().numpy()

            # Split predictions and tags back into sentences
            batch_size, seq_len = batch['tokens'].size()
            for i in range(batch_size):
                pred_seq = preds[i * seq_len:(i + 1) * seq_len].tolist()
                tag_seq = tags[i * seq_len:(i + 1) * seq_len].tolist()
                # Truncate padding
                valid_length = batch['length'][i].item()
                pred_seq = [idx2tag[p] for p in pred_seq[:valid_length]]
                tag_seq = [idx2tag[t] for t in tag_seq[:valid_length]]
                all_preds.append(pred_seq)
                all_tags.append(tag_seq)

    return epoch_loss / len(dataloader), all_preds, all_tags

# %%
# Training loop
NUM_EPOCHS = 30


global_best_valid_loss = float('inf')  # Store the best validation loss across all hyperparameter sets
best_model_filename = ""  # Store the filename of the best global model

# Iterate through all hyperparameter combinations
for EMBED_DIM, HIDDEN_DIM, LSTM_LAYERS, DROPOUT_RATE in product(embed_dims, hidden_dims, lstm_layers, dropout_rates):
    early_stopping = EarlyStopping(patience=3, min_delta=0.001)
    best_valid_loss = float('inf')
    best_model_for_params = ""  # Track the best model filename for the current hyperparameter combination
    
    # Reinitialize model and optimizer for each hyperparameter combination
    model = BiLSTM_NER(VOCAB_SIZE, EMBED_DIM, HIDDEN_DIM, TAGSET_SIZE, padding_idx=word2idx['<PAD>'], lstm_layers=LSTM_LAYERS, dropout_rate=DROPOUT_RATE)
    model.to(device)
    
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-5)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2)

    print(f"Training with BATCH_SIZE={BATCH_SIZE}, EMBED_DIM={EMBED_DIM}, HIDDEN_DIM={HIDDEN_DIM}, LSTM_LAYERS={LSTM_LAYERS}, DROPOUT_RATE={DROPOUT_RATE}, NUM_EPOCHS={NUM_EPOCHS}")
    
    for epoch in range(NUM_EPOCHS):
        train_loss = train(model, train_loader, optimizer, criterion, device)
        valid_loss, valid_preds, valid_tags = evaluate(model, valid_loader, criterion, device)

        # Calculate F1 score
        f1 = f1_score(valid_tags, valid_preds)

        # Reduce learning rate if validation loss plateaus
        scheduler.step(valid_loss)

        print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
        print(f"Train Loss: {train_loss:.4f} | Valid Loss: {valid_loss:.4f} | Valid F1 Score: {f1:.4f}")

        # Check for early stopping
        if early_stopping.step(valid_loss):
            print("Early stopping triggered.")
            break

        # Save best model with parameter values in filename
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            model_filename = f"best_model_E{epoch+1}_BS{BATCH_SIZE}_ED{EMBED_DIM}_HD{HIDDEN_DIM}_LL{LSTM_LAYERS}_DO{DROPOUT_RATE}.pt"
            
            # Remove previous best model for this parameter set if exists
            if best_model_for_params:
                os.remove(best_model_for_params)
            
            torch.save({
                'epoch': epoch+1,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'valid_loss': valid_loss
            }, model_filename)
            best_model_for_params = model_filename
            print(f"Saved Best Model: {model_filename}")

            # Update global best model
            if valid_loss < global_best_valid_loss:
                global_best_valid_loss = valid_loss
                best_model_filename = model_filename

print(f"Best overall model saved as: {best_model_filename} with validation loss: {global_best_valid_loss:.4f}")
# Out:
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=1, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7684 | Valid Loss: 0.5713 | Valid F1 Score: 0.2094
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.4752 | Valid Loss: 0.3723 | Valid F1 Score: 0.4516
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.3459 | Valid Loss: 0.2836 | Valid F1 Score: 0.5777
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.2730 | Valid Loss: 0.2459 | Valid F1 Score: 0.6331
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.2262 | Valid Loss: 0.2055 | Valid F1 Score: 0.6873
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1895 | Valid Loss: 0.1861 | Valid F1 Score: 0.7207
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.1619 | Valid Loss: 0.1825 | Valid F1 Score: 0.7356
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.1396 | Valid Loss: 0.1714 | Valid F1 Score: 0.7519
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.1220 | Valid Loss: 0.1606 | Valid F1 Score: 0.7666
# Saved Best Model: best_model_E9_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 10/30
# Train Loss: 0.1073 | Valid Loss: 0.1627 | Valid F1 Score: 0.7709
# Epoch 11/30
# Train Loss: 0.0940 | Valid Loss: 0.1553 | Valid F1 Score: 0.7811
# Saved Best Model: best_model_E11_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 12/30
# Train Loss: 0.0853 | Valid Loss: 0.1488 | Valid F1 Score: 0.7909
# Saved Best Model: best_model_E12_BS64_ED100_HD256_LL1_DO0.3.pt
# Epoch 13/30
# Train Loss: 0.0754 | Valid Loss: 0.1612 | Valid F1 Score: 0.7957
# Epoch 14/30
# Train Loss: 0.0676 | Valid Loss: 0.1586 | Valid F1 Score: 0.8037
# Epoch 15/30
# Train Loss: 0.0607 | Valid Loss: 0.1578 | Valid F1 Score: 0.8074
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=1, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7968 | Valid Loss: 0.6137 | Valid F1 Score: 0.1417
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.5634 | Valid Loss: 0.4541 | Valid F1 Score: 0.3520
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.4602 | Valid Loss: 0.3677 | Valid F1 Score: 0.4518
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.3876 | Valid Loss: 0.2962 | Valid F1 Score: 0.5532
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.3360 | Valid Loss: 0.2602 | Valid F1 Score: 0.6035
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2980 | Valid Loss: 0.2400 | Valid F1 Score: 0.6361
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.2673 | Valid Loss: 0.2183 | Valid F1 Score: 0.6651
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.2444 | Valid Loss: 0.2063 | Valid F1 Score: 0.6898
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.2194 | Valid Loss: 0.1947 | Valid F1 Score: 0.7058
# Saved Best Model: best_model_E9_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.2042 | Valid Loss: 0.1854 | Valid F1 Score: 0.7279
# Saved Best Model: best_model_E10_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1891 | Valid Loss: 0.1709 | Valid F1 Score: 0.7390
# Saved Best Model: best_model_E11_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1742 | Valid Loss: 0.1672 | Valid F1 Score: 0.7506
# Saved Best Model: best_model_E12_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.1634 | Valid Loss: 0.1604 | Valid F1 Score: 0.7552
# Saved Best Model: best_model_E13_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.1514 | Valid Loss: 0.1548 | Valid F1 Score: 0.7602
# Saved Best Model: best_model_E14_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 15/30
# Train Loss: 0.1425 | Valid Loss: 0.1548 | Valid F1 Score: 0.7726
# Saved Best Model: best_model_E15_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.1338 | Valid Loss: 0.1481 | Valid F1 Score: 0.7786
# Saved Best Model: best_model_E16_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 17/30
# Train Loss: 0.1262 | Valid Loss: 0.1477 | Valid F1 Score: 0.7900
# Saved Best Model: best_model_E17_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 18/30
# Train Loss: 0.1180 | Valid Loss: 0.1452 | Valid F1 Score: 0.7928
# Saved Best Model: best_model_E18_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 19/30
# Train Loss: 0.1112 | Valid Loss: 0.1407 | Valid F1 Score: 0.7973
# Saved Best Model: best_model_E19_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 20/30
# Train Loss: 0.1036 | Valid Loss: 0.1405 | Valid F1 Score: 0.8020
# Saved Best Model: best_model_E20_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 21/30
# Train Loss: 0.1000 | Valid Loss: 0.1429 | Valid F1 Score: 0.7988
# Epoch 22/30
# Train Loss: 0.0947 | Valid Loss: 0.1313 | Valid F1 Score: 0.8105
# Saved Best Model: best_model_E22_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 23/30
# Train Loss: 0.0893 | Valid Loss: 0.1343 | Valid F1 Score: 0.8166
# Epoch 24/30
# Train Loss: 0.0834 | Valid Loss: 0.1343 | Valid F1 Score: 0.8177
# Epoch 25/30
# Train Loss: 0.0833 | Valid Loss: 0.1286 | Valid F1 Score: 0.8239
# Saved Best Model: best_model_E25_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 26/30
# Train Loss: 0.0764 | Valid Loss: 0.1292 | Valid F1 Score: 0.8264
# Epoch 27/30
# Train Loss: 0.0733 | Valid Loss: 0.1282 | Valid F1 Score: 0.8238
# Saved Best Model: best_model_E27_BS64_ED100_HD256_LL1_DO0.5.pt
# Epoch 28/30
# Train Loss: 0.0686 | Valid Loss: 0.1281 | Valid F1 Score: 0.8302
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=2, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7105 | Valid Loss: 0.4939 | Valid F1 Score: 0.3085
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3903 | Valid Loss: 0.3066 | Valid F1 Score: 0.5441
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2713 | Valid Loss: 0.2359 | Valid F1 Score: 0.6554
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.2108 | Valid Loss: 0.2203 | Valid F1 Score: 0.6892
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1693 | Valid Loss: 0.1953 | Valid F1 Score: 0.7219
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1433 | Valid Loss: 0.1895 | Valid F1 Score: 0.7374
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.1209 | Valid Loss: 0.1618 | Valid F1 Score: 0.7546
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.1042 | Valid Loss: 0.1553 | Valid F1 Score: 0.7716
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL2_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0880 | Valid Loss: 0.1639 | Valid F1 Score: 0.7717
# Epoch 10/30
# Train Loss: 0.0782 | Valid Loss: 0.1624 | Valid F1 Score: 0.7874
# Epoch 11/30
# Train Loss: 0.0689 | Valid Loss: 0.1569 | Valid F1 Score: 0.7913
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=2, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7432 | Valid Loss: 0.5449 | Valid F1 Score: 0.2505
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4790 | Valid Loss: 0.3657 | Valid F1 Score: 0.4755
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.3723 | Valid Loss: 0.2891 | Valid F1 Score: 0.5665
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.3159 | Valid Loss: 0.2457 | Valid F1 Score: 0.6270
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2807 | Valid Loss: 0.2179 | Valid F1 Score: 0.6740
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2491 | Valid Loss: 0.2081 | Valid F1 Score: 0.6829
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.2266 | Valid Loss: 0.1972 | Valid F1 Score: 0.6856
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.2047 | Valid Loss: 0.1892 | Valid F1 Score: 0.7072
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1912 | Valid Loss: 0.1778 | Valid F1 Score: 0.7237
# Saved Best Model: best_model_E9_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1746 | Valid Loss: 0.1711 | Valid F1 Score: 0.7243
# Saved Best Model: best_model_E10_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1632 | Valid Loss: 0.1672 | Valid F1 Score: 0.7264
# Saved Best Model: best_model_E11_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1491 | Valid Loss: 0.1732 | Valid F1 Score: 0.7308
# Epoch 13/30
# Train Loss: 0.1419 | Valid Loss: 0.1507 | Valid F1 Score: 0.7604
# Saved Best Model: best_model_E13_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.1342 | Valid Loss: 0.1507 | Valid F1 Score: 0.7619
# Saved Best Model: best_model_E14_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 15/30
# Train Loss: 0.1257 | Valid Loss: 0.1483 | Valid F1 Score: 0.7647
# Saved Best Model: best_model_E15_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.1173 | Valid Loss: 0.1471 | Valid F1 Score: 0.7723
# Saved Best Model: best_model_E16_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 17/30
# Train Loss: 0.1107 | Valid Loss: 0.1449 | Valid F1 Score: 0.7842
# Saved Best Model: best_model_E17_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 18/30
# Train Loss: 0.1059 | Valid Loss: 0.1439 | Valid F1 Score: 0.7797
# Saved Best Model: best_model_E18_BS64_ED100_HD256_LL2_DO0.5.pt
# Epoch 19/30
# Train Loss: 0.0990 | Valid Loss: 0.1479 | Valid F1 Score: 0.7727
# Epoch 20/30
# Train Loss: 0.0955 | Valid Loss: 0.1475 | Valid F1 Score: 0.7739
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=3, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7314 | Valid Loss: 0.5211 | Valid F1 Score: 0.2637
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3968 | Valid Loss: 0.3002 | Valid F1 Score: 0.5321
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2739 | Valid Loss: 0.2443 | Valid F1 Score: 0.6470
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.2094 | Valid Loss: 0.2024 | Valid F1 Score: 0.7011
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1669 | Valid Loss: 0.1805 | Valid F1 Score: 0.7434
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1383 | Valid Loss: 0.1760 | Valid F1 Score: 0.7500
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.1169 | Valid Loss: 0.1630 | Valid F1 Score: 0.7614
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.1007 | Valid Loss: 0.1626 | Valid F1 Score: 0.7843
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0846 | Valid Loss: 0.1572 | Valid F1 Score: 0.7865
# Saved Best Model: best_model_E9_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 10/30
# Train Loss: 0.0744 | Valid Loss: 0.1663 | Valid F1 Score: 0.8017
# Epoch 11/30
# Train Loss: 0.0659 | Valid Loss: 0.1550 | Valid F1 Score: 0.8041
# Saved Best Model: best_model_E11_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 12/30
# Train Loss: 0.0581 | Valid Loss: 0.1497 | Valid F1 Score: 0.8083
# Saved Best Model: best_model_E12_BS64_ED100_HD256_LL3_DO0.3.pt
# Epoch 13/30
# Train Loss: 0.0537 | Valid Loss: 0.1682 | Valid F1 Score: 0.8031
# Epoch 14/30
# Train Loss: 0.0483 | Valid Loss: 0.1597 | Valid F1 Score: 0.8041
# Epoch 15/30
# Train Loss: 0.0440 | Valid Loss: 0.1522 | Valid F1 Score: 0.8170
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=256, LSTM_LAYERS=3, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7644 | Valid Loss: 0.6133 | Valid F1 Score: 0.2199
# Saved Best Model: best_model_E1_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4910 | Valid Loss: 0.3810 | Valid F1 Score: 0.4231
# Saved Best Model: best_model_E2_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.3769 | Valid Loss: 0.3166 | Valid F1 Score: 0.5335
# Saved Best Model: best_model_E3_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.3198 | Valid Loss: 0.2616 | Valid F1 Score: 0.6232
# Saved Best Model: best_model_E4_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2826 | Valid Loss: 0.2514 | Valid F1 Score: 0.6530
# Saved Best Model: best_model_E5_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2509 | Valid Loss: 0.2388 | Valid F1 Score: 0.6852
# Saved Best Model: best_model_E6_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.2253 | Valid Loss: 0.2146 | Valid F1 Score: 0.6983
# Saved Best Model: best_model_E7_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.2054 | Valid Loss: 0.1970 | Valid F1 Score: 0.7262
# Saved Best Model: best_model_E8_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1878 | Valid Loss: 0.1967 | Valid F1 Score: 0.7298
# Saved Best Model: best_model_E9_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1738 | Valid Loss: 0.1921 | Valid F1 Score: 0.7451
# Saved Best Model: best_model_E10_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1611 | Valid Loss: 0.1841 | Valid F1 Score: 0.7560
# Saved Best Model: best_model_E11_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1507 | Valid Loss: 0.1742 | Valid F1 Score: 0.7691
# Saved Best Model: best_model_E12_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.1389 | Valid Loss: 0.1866 | Valid F1 Score: 0.7751
# Epoch 14/30
# Train Loss: 0.1291 | Valid Loss: 0.1886 | Valid F1 Score: 0.7701
# Epoch 15/30
# Train Loss: 0.1229 | Valid Loss: 0.1713 | Valid F1 Score: 0.7859
# Saved Best Model: best_model_E15_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.1163 | Valid Loss: 0.1783 | Valid F1 Score: 0.7898
# Epoch 17/30
# Train Loss: 0.1090 | Valid Loss: 0.1835 | Valid F1 Score: 0.7853
# Epoch 18/30
# Train Loss: 0.1024 | Valid Loss: 0.1505 | Valid F1 Score: 0.8004
# Saved Best Model: best_model_E18_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 19/30
# Train Loss: 0.0984 | Valid Loss: 0.1567 | Valid F1 Score: 0.8001
# Epoch 20/30
# Train Loss: 0.0912 | Valid Loss: 0.1465 | Valid F1 Score: 0.8154
# Saved Best Model: best_model_E20_BS64_ED100_HD256_LL3_DO0.5.pt
# Epoch 21/30
# Train Loss: 0.0861 | Valid Loss: 0.1597 | Valid F1 Score: 0.8022
# Epoch 22/30
# Train Loss: 0.0829 | Valid Loss: 0.1568 | Valid F1 Score: 0.8061
# Epoch 23/30
# Train Loss: 0.0786 | Valid Loss: 0.1816 | Valid F1 Score: 0.7999
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=1, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6883 | Valid Loss: 0.5016 | Valid F1 Score: 0.3174
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.4113 | Valid Loss: 0.3426 | Valid F1 Score: 0.5103
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.3013 | Valid Loss: 0.2803 | Valid F1 Score: 0.6007
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.2352 | Valid Loss: 0.2386 | Valid F1 Score: 0.6603
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1906 | Valid Loss: 0.2135 | Valid F1 Score: 0.6894
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1583 | Valid Loss: 0.1999 | Valid F1 Score: 0.7118
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.1308 | Valid Loss: 0.1995 | Valid F1 Score: 0.7302
# Saved Best Model: best_model_E7_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.1115 | Valid Loss: 0.1893 | Valid F1 Score: 0.7420
# Saved Best Model: best_model_E8_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0943 | Valid Loss: 0.1739 | Valid F1 Score: 0.7621
# Saved Best Model: best_model_E9_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 10/30
# Train Loss: 0.0824 | Valid Loss: 0.1847 | Valid F1 Score: 0.7667
# Epoch 11/30
# Train Loss: 0.0704 | Valid Loss: 0.1704 | Valid F1 Score: 0.7756
# Saved Best Model: best_model_E11_BS64_ED100_HD512_LL1_DO0.3.pt
# Epoch 12/30
# Train Loss: 0.0611 | Valid Loss: 0.1750 | Valid F1 Score: 0.7737
# Epoch 13/30
# Train Loss: 0.0540 | Valid Loss: 0.1794 | Valid F1 Score: 0.7799
# Epoch 14/30
# Train Loss: 0.0482 | Valid Loss: 0.1822 | Valid F1 Score: 0.7771
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=1, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7235 | Valid Loss: 0.5577 | Valid F1 Score: 0.2617
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4972 | Valid Loss: 0.3963 | Valid F1 Score: 0.4344
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.4009 | Valid Loss: 0.3183 | Valid F1 Score: 0.5352
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.3371 | Valid Loss: 0.2690 | Valid F1 Score: 0.5925
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2939 | Valid Loss: 0.2387 | Valid F1 Score: 0.6455
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2605 | Valid Loss: 0.2231 | Valid F1 Score: 0.6614
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.2342 | Valid Loss: 0.2102 | Valid F1 Score: 0.6848
# Saved Best Model: best_model_E7_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.2124 | Valid Loss: 0.1906 | Valid F1 Score: 0.7128
# Saved Best Model: best_model_E8_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1910 | Valid Loss: 0.1886 | Valid F1 Score: 0.7212
# Saved Best Model: best_model_E9_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1757 | Valid Loss: 0.1780 | Valid F1 Score: 0.7362
# Saved Best Model: best_model_E10_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1619 | Valid Loss: 0.1661 | Valid F1 Score: 0.7567
# Saved Best Model: best_model_E11_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1501 | Valid Loss: 0.1601 | Valid F1 Score: 0.7666
# Saved Best Model: best_model_E12_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.1385 | Valid Loss: 0.1558 | Valid F1 Score: 0.7720
# Saved Best Model: best_model_E13_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.1299 | Valid Loss: 0.1564 | Valid F1 Score: 0.7745
# Epoch 15/30
# Train Loss: 0.1196 | Valid Loss: 0.1463 | Valid F1 Score: 0.7871
# Saved Best Model: best_model_E15_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.1120 | Valid Loss: 0.1496 | Valid F1 Score: 0.7860
# Epoch 17/30
# Train Loss: 0.1046 | Valid Loss: 0.1409 | Valid F1 Score: 0.7924
# Saved Best Model: best_model_E17_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 18/30
# Train Loss: 0.0989 | Valid Loss: 0.1416 | Valid F1 Score: 0.7937
# Epoch 19/30
# Train Loss: 0.0918 | Valid Loss: 0.1392 | Valid F1 Score: 0.7961
# Saved Best Model: best_model_E19_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 20/30
# Train Loss: 0.0870 | Valid Loss: 0.1449 | Valid F1 Score: 0.8090
# Epoch 21/30
# Train Loss: 0.0811 | Valid Loss: 0.1382 | Valid F1 Score: 0.8091
# Saved Best Model: best_model_E21_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 22/30
# Train Loss: 0.0785 | Valid Loss: 0.1313 | Valid F1 Score: 0.8080
# Saved Best Model: best_model_E22_BS64_ED100_HD512_LL1_DO0.5.pt
# Epoch 23/30
# Train Loss: 0.0736 | Valid Loss: 0.1351 | Valid F1 Score: 0.8146
# Epoch 24/30
# Train Loss: 0.0693 | Valid Loss: 0.1351 | Valid F1 Score: 0.8203
# Epoch 25/30
# Train Loss: 0.0670 | Valid Loss: 0.1350 | Valid F1 Score: 0.8154
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=2, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6392 | Valid Loss: 0.4169 | Valid F1 Score: 0.4117
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3404 | Valid Loss: 0.2673 | Valid F1 Score: 0.5857
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2369 | Valid Loss: 0.2063 | Valid F1 Score: 0.6957
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.1740 | Valid Loss: 0.1874 | Valid F1 Score: 0.7081
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1336 | Valid Loss: 0.1779 | Valid F1 Score: 0.7267
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1046 | Valid Loss: 0.1735 | Valid F1 Score: 0.7457
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.0837 | Valid Loss: 0.1733 | Valid F1 Score: 0.7465
# Saved Best Model: best_model_E7_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.0685 | Valid Loss: 0.1629 | Valid F1 Score: 0.7694
# Saved Best Model: best_model_E8_BS64_ED100_HD512_LL2_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0570 | Valid Loss: 0.1713 | Valid F1 Score: 0.7742
# Epoch 10/30
# Train Loss: 0.0475 | Valid Loss: 0.1668 | Valid F1 Score: 0.7789
# Epoch 11/30
# Train Loss: 0.0405 | Valid Loss: 0.1665 | Valid F1 Score: 0.7927
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=2, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6764 | Valid Loss: 0.4797 | Valid F1 Score: 0.3363
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4252 | Valid Loss: 0.3224 | Valid F1 Score: 0.5370
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.3331 | Valid Loss: 0.2622 | Valid F1 Score: 0.6281
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.2766 | Valid Loss: 0.2252 | Valid F1 Score: 0.6720
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2394 | Valid Loss: 0.2125 | Valid F1 Score: 0.6972
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2093 | Valid Loss: 0.1883 | Valid F1 Score: 0.7313
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1859 | Valid Loss: 0.1716 | Valid F1 Score: 0.7456
# Saved Best Model: best_model_E7_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1673 | Valid Loss: 0.1750 | Valid F1 Score: 0.7491
# Epoch 9/30
# Train Loss: 0.1516 | Valid Loss: 0.1667 | Valid F1 Score: 0.7523
# Saved Best Model: best_model_E9_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1381 | Valid Loss: 0.1583 | Valid F1 Score: 0.7766
# Saved Best Model: best_model_E10_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1266 | Valid Loss: 0.1582 | Valid F1 Score: 0.7617
# Saved Best Model: best_model_E11_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1179 | Valid Loss: 0.1573 | Valid F1 Score: 0.7656
# Saved Best Model: best_model_E12_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.1069 | Valid Loss: 0.1532 | Valid F1 Score: 0.7843
# Saved Best Model: best_model_E13_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.1017 | Valid Loss: 0.1531 | Valid F1 Score: 0.7846
# Saved Best Model: best_model_E14_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 15/30
# Train Loss: 0.0954 | Valid Loss: 0.1514 | Valid F1 Score: 0.8025
# Saved Best Model: best_model_E15_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.0871 | Valid Loss: 0.1411 | Valid F1 Score: 0.7972
# Saved Best Model: best_model_E16_BS64_ED100_HD512_LL2_DO0.5.pt
# Epoch 17/30
# Train Loss: 0.0829 | Valid Loss: 0.1463 | Valid F1 Score: 0.8058
# Epoch 18/30
# Train Loss: 0.0755 | Valid Loss: 0.1430 | Valid F1 Score: 0.8073
# Epoch 19/30
# Train Loss: 0.0723 | Valid Loss: 0.1477 | Valid F1 Score: 0.8158
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=3, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6453 | Valid Loss: 0.4119 | Valid F1 Score: 0.3857
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3342 | Valid Loss: 0.2555 | Valid F1 Score: 0.6194
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2297 | Valid Loss: 0.2010 | Valid F1 Score: 0.6994
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.1723 | Valid Loss: 0.1840 | Valid F1 Score: 0.7201
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1322 | Valid Loss: 0.1618 | Valid F1 Score: 0.7543
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1030 | Valid Loss: 0.1596 | Valid F1 Score: 0.7616
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.0842 | Valid Loss: 0.1638 | Valid F1 Score: 0.7494
# Epoch 8/30
# Train Loss: 0.0676 | Valid Loss: 0.1514 | Valid F1 Score: 0.7754
# Saved Best Model: best_model_E8_BS64_ED100_HD512_LL3_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0554 | Valid Loss: 0.1581 | Valid F1 Score: 0.7715
# Epoch 10/30
# Train Loss: 0.0472 | Valid Loss: 0.1561 | Valid F1 Score: 0.7850
# Epoch 11/30
# Train Loss: 0.0419 | Valid Loss: 0.1668 | Valid F1 Score: 0.7849
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=100, HIDDEN_DIM=512, LSTM_LAYERS=3, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6839 | Valid Loss: 0.4775 | Valid F1 Score: 0.3027
# Saved Best Model: best_model_E1_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4267 | Valid Loss: 0.3308 | Valid F1 Score: 0.5073
# Saved Best Model: best_model_E2_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.3329 | Valid Loss: 0.2729 | Valid F1 Score: 0.5899
# Saved Best Model: best_model_E3_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.2769 | Valid Loss: 0.2284 | Valid F1 Score: 0.6762
# Saved Best Model: best_model_E4_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2345 | Valid Loss: 0.1973 | Valid F1 Score: 0.7046
# Saved Best Model: best_model_E5_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2055 | Valid Loss: 0.1877 | Valid F1 Score: 0.7139
# Saved Best Model: best_model_E6_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1826 | Valid Loss: 0.1781 | Valid F1 Score: 0.7405
# Saved Best Model: best_model_E7_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1614 | Valid Loss: 0.1701 | Valid F1 Score: 0.7487
# Saved Best Model: best_model_E8_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1461 | Valid Loss: 0.1638 | Valid F1 Score: 0.7509
# Saved Best Model: best_model_E9_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1321 | Valid Loss: 0.1583 | Valid F1 Score: 0.7716
# Saved Best Model: best_model_E10_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1198 | Valid Loss: 0.1704 | Valid F1 Score: 0.7498
# Epoch 12/30
# Train Loss: 0.1087 | Valid Loss: 0.1587 | Valid F1 Score: 0.7621
# Epoch 13/30
# Train Loss: 0.0995 | Valid Loss: 0.1478 | Valid F1 Score: 0.7939
# Saved Best Model: best_model_E13_BS64_ED100_HD512_LL3_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.0925 | Valid Loss: 0.1496 | Valid F1 Score: 0.7937
# Epoch 15/30
# Train Loss: 0.0857 | Valid Loss: 0.1578 | Valid F1 Score: 0.7754
# Epoch 16/30
# Train Loss: 0.0767 | Valid Loss: 0.1502 | Valid F1 Score: 0.7953
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=1, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7038 | Valid Loss: 0.4829 | Valid F1 Score: 0.3166
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3971 | Valid Loss: 0.3011 | Valid F1 Score: 0.5599
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2736 | Valid Loss: 0.2280 | Valid F1 Score: 0.6535
# Saved Best Model: best_model_E3_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.2048 | Valid Loss: 0.1978 | Valid F1 Score: 0.6910
# Saved Best Model: best_model_E4_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1590 | Valid Loss: 0.1732 | Valid F1 Score: 0.7296
# Saved Best Model: best_model_E5_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.1281 | Valid Loss: 0.1707 | Valid F1 Score: 0.7346
# Saved Best Model: best_model_E6_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.1055 | Valid Loss: 0.1537 | Valid F1 Score: 0.7724
# Saved Best Model: best_model_E7_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.0872 | Valid Loss: 0.1465 | Valid F1 Score: 0.7734
# Saved Best Model: best_model_E8_BS64_ED200_HD256_LL1_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0730 | Valid Loss: 0.1537 | Valid F1 Score: 0.7735
# Epoch 10/30
# Train Loss: 0.0626 | Valid Loss: 0.1494 | Valid F1 Score: 0.7845
# Epoch 11/30
# Train Loss: 0.0520 | Valid Loss: 0.1517 | Valid F1 Score: 0.7888
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=1, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7600 | Valid Loss: 0.5657 | Valid F1 Score: 0.2003
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.5121 | Valid Loss: 0.4042 | Valid F1 Score: 0.4249
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.4011 | Valid Loss: 0.3036 | Valid F1 Score: 0.5636
# Saved Best Model: best_model_E3_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.3253 | Valid Loss: 0.2538 | Valid F1 Score: 0.6276
# Saved Best Model: best_model_E4_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2745 | Valid Loss: 0.2221 | Valid F1 Score: 0.6644
# Saved Best Model: best_model_E5_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.2365 | Valid Loss: 0.2021 | Valid F1 Score: 0.6945
# Saved Best Model: best_model_E6_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.2111 | Valid Loss: 0.1823 | Valid F1 Score: 0.7177
# Saved Best Model: best_model_E7_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1874 | Valid Loss: 0.1788 | Valid F1 Score: 0.7292
# Saved Best Model: best_model_E8_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1670 | Valid Loss: 0.1636 | Valid F1 Score: 0.7460
# Saved Best Model: best_model_E9_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1504 | Valid Loss: 0.1614 | Valid F1 Score: 0.7488
# Saved Best Model: best_model_E10_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1410 | Valid Loss: 0.1528 | Valid F1 Score: 0.7639
# Saved Best Model: best_model_E11_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1293 | Valid Loss: 0.1533 | Valid F1 Score: 0.7574
# Epoch 13/30
# Train Loss: 0.1176 | Valid Loss: 0.1480 | Valid F1 Score: 0.7605
# Saved Best Model: best_model_E13_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.1080 | Valid Loss: 0.1454 | Valid F1 Score: 0.7786
# Saved Best Model: best_model_E14_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 15/30
# Train Loss: 0.0995 | Valid Loss: 0.1482 | Valid F1 Score: 0.7737
# Epoch 16/30
# Train Loss: 0.0927 | Valid Loss: 0.1424 | Valid F1 Score: 0.7849
# Saved Best Model: best_model_E16_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 17/30
# Train Loss: 0.0855 | Valid Loss: 0.1389 | Valid F1 Score: 0.7918
# Saved Best Model: best_model_E17_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 18/30
# Train Loss: 0.0813 | Valid Loss: 0.1380 | Valid F1 Score: 0.7959
# Saved Best Model: best_model_E18_BS64_ED200_HD256_LL1_DO0.5.pt
# Epoch 19/30
# Train Loss: 0.0748 | Valid Loss: 0.1451 | Valid F1 Score: 0.7873
# Epoch 20/30
# Train Loss: 0.0717 | Valid Loss: 0.1394 | Valid F1 Score: 0.8031
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=2, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6575 | Valid Loss: 0.3945 | Valid F1 Score: 0.4109
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3035 | Valid Loss: 0.2386 | Valid F1 Score: 0.6616
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.1895 | Valid Loss: 0.2034 | Valid F1 Score: 0.7025
# Saved Best Model: best_model_E3_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.1359 | Valid Loss: 0.1720 | Valid F1 Score: 0.7462
# Saved Best Model: best_model_E4_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1039 | Valid Loss: 0.1728 | Valid F1 Score: 0.7443
# Epoch 6/30
# Train Loss: 0.0815 | Valid Loss: 0.1573 | Valid F1 Score: 0.7755
# Saved Best Model: best_model_E6_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.0662 | Valid Loss: 0.1486 | Valid F1 Score: 0.7809
# Saved Best Model: best_model_E7_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.0542 | Valid Loss: 0.1483 | Valid F1 Score: 0.7970
# Saved Best Model: best_model_E8_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 9/30
# Train Loss: 0.0471 | Valid Loss: 0.1477 | Valid F1 Score: 0.8092
# Saved Best Model: best_model_E9_BS64_ED200_HD256_LL2_DO0.3.pt
# Epoch 10/30
# Train Loss: 0.0393 | Valid Loss: 0.1618 | Valid F1 Score: 0.8028
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=2, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7052 | Valid Loss: 0.4878 | Valid F1 Score: 0.3376
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.3989 | Valid Loss: 0.2982 | Valid F1 Score: 0.5844
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.2962 | Valid Loss: 0.2542 | Valid F1 Score: 0.6630
# Saved Best Model: best_model_E3_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.2419 | Valid Loss: 0.2562 | Valid F1 Score: 0.6903
# Epoch 5/30
# Train Loss: 0.2112 | Valid Loss: 0.2303 | Valid F1 Score: 0.7220
# Saved Best Model: best_model_E5_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.1834 | Valid Loss: 0.2172 | Valid F1 Score: 0.7416
# Saved Best Model: best_model_E6_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1648 | Valid Loss: 0.2016 | Valid F1 Score: 0.7520
# Saved Best Model: best_model_E7_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1495 | Valid Loss: 0.1998 | Valid F1 Score: 0.7637
# Saved Best Model: best_model_E8_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1336 | Valid Loss: 0.1897 | Valid F1 Score: 0.7752
# Saved Best Model: best_model_E9_BS64_ED200_HD256_LL2_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1224 | Valid Loss: 0.2044 | Valid F1 Score: 0.7819
# Epoch 11/30
# Train Loss: 0.1132 | Valid Loss: 0.2047 | Valid F1 Score: 0.7846
# Epoch 12/30
# Train Loss: 0.1030 | Valid Loss: 0.1999 | Valid F1 Score: 0.7884
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=3, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6759 | Valid Loss: 0.4010 | Valid F1 Score: 0.3890
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL3_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3080 | Valid Loss: 0.2385 | Valid F1 Score: 0.6344
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL3_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.1953 | Valid Loss: 0.2476 | Valid F1 Score: 0.6656
# Epoch 4/30
# Train Loss: 0.1406 | Valid Loss: 0.1714 | Valid F1 Score: 0.7475
# Saved Best Model: best_model_E4_BS64_ED200_HD256_LL3_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1066 | Valid Loss: 0.1754 | Valid F1 Score: 0.7500
# Epoch 6/30
# Train Loss: 0.0858 | Valid Loss: 0.1950 | Valid F1 Score: 0.7514
# Epoch 7/30
# Train Loss: 0.0704 | Valid Loss: 0.1815 | Valid F1 Score: 0.7711
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=256, LSTM_LAYERS=3, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.7143 | Valid Loss: 0.4731 | Valid F1 Score: 0.3130
# Saved Best Model: best_model_E1_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4000 | Valid Loss: 0.2915 | Valid F1 Score: 0.5600
# Saved Best Model: best_model_E2_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.2964 | Valid Loss: 0.2614 | Valid F1 Score: 0.6497
# Saved Best Model: best_model_E3_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.2438 | Valid Loss: 0.2118 | Valid F1 Score: 0.7093
# Saved Best Model: best_model_E4_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2080 | Valid Loss: 0.1810 | Valid F1 Score: 0.7358
# Saved Best Model: best_model_E5_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.1809 | Valid Loss: 0.1624 | Valid F1 Score: 0.7645
# Saved Best Model: best_model_E6_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1631 | Valid Loss: 0.1630 | Valid F1 Score: 0.7670
# Epoch 8/30
# Train Loss: 0.1491 | Valid Loss: 0.1460 | Valid F1 Score: 0.7853
# Saved Best Model: best_model_E8_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1333 | Valid Loss: 0.1538 | Valid F1 Score: 0.7855
# Epoch 10/30
# Train Loss: 0.1212 | Valid Loss: 0.1458 | Valid F1 Score: 0.7990
# Saved Best Model: best_model_E10_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1131 | Valid Loss: 0.1389 | Valid F1 Score: 0.8016
# Saved Best Model: best_model_E11_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.1034 | Valid Loss: 0.1345 | Valid F1 Score: 0.8122
# Saved Best Model: best_model_E12_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.0976 | Valid Loss: 0.1334 | Valid F1 Score: 0.8178
# Saved Best Model: best_model_E13_BS64_ED200_HD256_LL3_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.0890 | Valid Loss: 0.1389 | Valid F1 Score: 0.8231
# Epoch 15/30
# Train Loss: 0.0849 | Valid Loss: 0.1417 | Valid F1 Score: 0.8141
# Epoch 16/30
# Train Loss: 0.0782 | Valid Loss: 0.1359 | Valid F1 Score: 0.8306
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=1, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6282 | Valid Loss: 0.4164 | Valid F1 Score: 0.4218
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.3295 | Valid Loss: 0.2843 | Valid F1 Score: 0.5703
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.2231 | Valid Loss: 0.2227 | Valid F1 Score: 0.6617
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.1608 | Valid Loss: 0.1957 | Valid F1 Score: 0.6970
# Saved Best Model: best_model_E4_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.1210 | Valid Loss: 0.1903 | Valid F1 Score: 0.6997
# Saved Best Model: best_model_E5_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.0942 | Valid Loss: 0.1749 | Valid F1 Score: 0.7255
# Saved Best Model: best_model_E6_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.0734 | Valid Loss: 0.1727 | Valid F1 Score: 0.7378
# Saved Best Model: best_model_E7_BS64_ED200_HD512_LL1_DO0.3.pt
# Epoch 8/30
# Train Loss: 0.0590 | Valid Loss: 0.1774 | Valid F1 Score: 0.7298
# Epoch 9/30
# Train Loss: 0.0476 | Valid Loss: 0.2124 | Valid F1 Score: 0.7082
# Epoch 10/30
# Train Loss: 0.0404 | Valid Loss: 0.1889 | Valid F1 Score: 0.7360
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=1, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6886 | Valid Loss: 0.4799 | Valid F1 Score: 0.3479
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.4300 | Valid Loss: 0.3204 | Valid F1 Score: 0.5340
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.3271 | Valid Loss: 0.2564 | Valid F1 Score: 0.6128
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.2673 | Valid Loss: 0.2122 | Valid F1 Score: 0.6722
# Saved Best Model: best_model_E4_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.2236 | Valid Loss: 0.1855 | Valid F1 Score: 0.7173
# Saved Best Model: best_model_E5_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.1955 | Valid Loss: 0.1697 | Valid F1 Score: 0.7414
# Saved Best Model: best_model_E6_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1709 | Valid Loss: 0.1639 | Valid F1 Score: 0.7519
# Saved Best Model: best_model_E7_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1524 | Valid Loss: 0.1569 | Valid F1 Score: 0.7668
# Saved Best Model: best_model_E8_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.1353 | Valid Loss: 0.1517 | Valid F1 Score: 0.7712
# Saved Best Model: best_model_E9_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.1206 | Valid Loss: 0.1482 | Valid F1 Score: 0.7804
# Saved Best Model: best_model_E10_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.1103 | Valid Loss: 0.1489 | Valid F1 Score: 0.7909
# Epoch 12/30
# Train Loss: 0.0992 | Valid Loss: 0.1401 | Valid F1 Score: 0.7966
# Saved Best Model: best_model_E12_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.0912 | Valid Loss: 0.1386 | Valid F1 Score: 0.8020
# Saved Best Model: best_model_E13_BS64_ED200_HD512_LL1_DO0.5.pt
# Epoch 14/30
# Train Loss: 0.0839 | Valid Loss: 0.1391 | Valid F1 Score: 0.8061
# Epoch 15/30
# Train Loss: 0.0782 | Valid Loss: 0.1431 | Valid F1 Score: 0.8122
# Epoch 16/30
# Train Loss: 0.0727 | Valid Loss: 0.1379 | Valid F1 Score: 0.8130
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=2, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.5784 | Valid Loss: 0.3265 | Valid F1 Score: 0.5203
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL2_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.2468 | Valid Loss: 0.2176 | Valid F1 Score: 0.6678
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL2_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.1469 | Valid Loss: 0.1632 | Valid F1 Score: 0.7423
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL2_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.0988 | Valid Loss: 0.1716 | Valid F1 Score: 0.7373
# Epoch 5/30
# Train Loss: 0.0683 | Valid Loss: 0.1475 | Valid F1 Score: 0.7918
# Saved Best Model: best_model_E5_BS64_ED200_HD512_LL2_DO0.3.pt
# Epoch 6/30
# Train Loss: 0.0522 | Valid Loss: 0.1440 | Valid F1 Score: 0.8030
# Saved Best Model: best_model_E6_BS64_ED200_HD512_LL2_DO0.3.pt
# Epoch 7/30
# Train Loss: 0.0385 | Valid Loss: 0.1717 | Valid F1 Score: 0.7708
# Epoch 8/30
# Train Loss: 0.0301 | Valid Loss: 0.1570 | Valid F1 Score: 0.8018
# Epoch 9/30
# Train Loss: 0.0249 | Valid Loss: 0.1782 | Valid F1 Score: 0.7949
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=2, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6273 | Valid Loss: 0.3906 | Valid F1 Score: 0.4579
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.3361 | Valid Loss: 0.2532 | Valid F1 Score: 0.6419
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.2467 | Valid Loss: 0.1906 | Valid F1 Score: 0.7232
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.1995 | Valid Loss: 0.1702 | Valid F1 Score: 0.7543
# Saved Best Model: best_model_E4_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.1624 | Valid Loss: 0.1523 | Valid F1 Score: 0.7791
# Saved Best Model: best_model_E5_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.1401 | Valid Loss: 0.1497 | Valid F1 Score: 0.7907
# Saved Best Model: best_model_E6_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1208 | Valid Loss: 0.1476 | Valid F1 Score: 0.7977
# Saved Best Model: best_model_E7_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1051 | Valid Loss: 0.1464 | Valid F1 Score: 0.8091
# Saved Best Model: best_model_E8_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 9/30
# Train Loss: 0.0936 | Valid Loss: 0.1466 | Valid F1 Score: 0.8202
# Epoch 10/30
# Train Loss: 0.0866 | Valid Loss: 0.1457 | Valid F1 Score: 0.8227
# Saved Best Model: best_model_E10_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 11/30
# Train Loss: 0.0763 | Valid Loss: 0.1417 | Valid F1 Score: 0.8221
# Saved Best Model: best_model_E11_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.0706 | Valid Loss: 0.1378 | Valid F1 Score: 0.8290
# Saved Best Model: best_model_E12_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 13/30
# Train Loss: 0.0644 | Valid Loss: 0.1380 | Valid F1 Score: 0.8262
# Epoch 14/30
# Train Loss: 0.0587 | Valid Loss: 0.1405 | Valid F1 Score: 0.8290
# Epoch 15/30
# Train Loss: 0.0565 | Valid Loss: 0.1361 | Valid F1 Score: 0.8368
# Saved Best Model: best_model_E15_BS64_ED200_HD512_LL2_DO0.5.pt
# Epoch 16/30
# Train Loss: 0.0523 | Valid Loss: 0.1445 | Valid F1 Score: 0.8311
# Epoch 17/30
# Train Loss: 0.0478 | Valid Loss: 0.1510 | Valid F1 Score: 0.8388
# Epoch 18/30
# Train Loss: 0.0451 | Valid Loss: 0.1447 | Valid F1 Score: 0.8371
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=3, DROPOUT_RATE=0.3, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.5843 | Valid Loss: 0.3240 | Valid F1 Score: 0.5209
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL3_DO0.3.pt
# Epoch 2/30
# Train Loss: 0.2476 | Valid Loss: 0.2275 | Valid F1 Score: 0.6835
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL3_DO0.3.pt
# Epoch 3/30
# Train Loss: 0.1504 | Valid Loss: 0.1760 | Valid F1 Score: 0.7609
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL3_DO0.3.pt
# Epoch 4/30
# Train Loss: 0.1003 | Valid Loss: 0.1513 | Valid F1 Score: 0.7746
# Saved Best Model: best_model_E4_BS64_ED200_HD512_LL3_DO0.3.pt
# Epoch 5/30
# Train Loss: 0.0725 | Valid Loss: 0.1862 | Valid F1 Score: 0.7913
# Epoch 6/30
# Train Loss: 0.0536 | Valid Loss: 0.2214 | Valid F1 Score: 0.7831
# Epoch 7/30
# Train Loss: 0.0430 | Valid Loss: 0.2426 | Valid F1 Score: 0.7951
# Early stopping triggered.
# Training with BATCH_SIZE=64, EMBED_DIM=200, HIDDEN_DIM=512, LSTM_LAYERS=3, DROPOUT_RATE=0.5, NUM_EPOCHS=30
# Epoch 1/30
# Train Loss: 0.6441 | Valid Loss: 0.3780 | Valid F1 Score: 0.4587
# Saved Best Model: best_model_E1_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 2/30
# Train Loss: 0.3429 | Valid Loss: 0.2465 | Valid F1 Score: 0.6327
# Saved Best Model: best_model_E2_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 3/30
# Train Loss: 0.2503 | Valid Loss: 0.1954 | Valid F1 Score: 0.6937
# Saved Best Model: best_model_E3_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 4/30
# Train Loss: 0.1951 | Valid Loss: 0.1703 | Valid F1 Score: 0.7395
# Saved Best Model: best_model_E4_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 5/30
# Train Loss: 0.1629 | Valid Loss: 0.1604 | Valid F1 Score: 0.7595
# Saved Best Model: best_model_E5_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 6/30
# Train Loss: 0.1371 | Valid Loss: 0.1572 | Valid F1 Score: 0.7784
# Saved Best Model: best_model_E6_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 7/30
# Train Loss: 0.1213 | Valid Loss: 0.1363 | Valid F1 Score: 0.7898
# Saved Best Model: best_model_E7_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 8/30
# Train Loss: 0.1060 | Valid Loss: 0.1385 | Valid F1 Score: 0.8030
# Epoch 9/30
# Train Loss: 0.0923 | Valid Loss: 0.1308 | Valid F1 Score: 0.8191
# Saved Best Model: best_model_E9_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 10/30
# Train Loss: 0.0839 | Valid Loss: 0.1369 | Valid F1 Score: 0.8155
# Epoch 11/30
# Train Loss: 0.0748 | Valid Loss: 0.1279 | Valid F1 Score: 0.8220
# Saved Best Model: best_model_E11_BS64_ED200_HD512_LL3_DO0.5.pt
# Epoch 12/30
# Train Loss: 0.0691 | Valid Loss: 0.1390 | Valid F1 Score: 0.8057
# Epoch 13/30
# Train Loss: 0.0648 | Valid Loss: 0.1355 | Valid F1 Score: 0.8154
# Epoch 14/30
# Train Loss: 0.0570 | Valid Loss: 0.1295 | Valid F1 Score: 0.8300
# Early stopping triggered.
# Best overall model saved as: best_model_E11_BS64_ED200_HD512_LL3_DO0.5.pt with validation loss: 0.1279

# %% [markdown]
# # 6. Model Evaluation

# %%
# Load the best model
checkpoint = torch.load(best_model_filename)

model.load_state_dict(checkpoint['model_state_dict'])

# # For continuous training
# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# epoch = checkpoint['epoch']


# Define prediction function
def predict(model, dataloader, device):
    model.eval()
    all_preds = []
    all_tags = []

    with torch.no_grad():
        for batch in dataloader:
            tokens = batch['tokens'].to(device)
            tags = batch['tags'].to(device)

            outputs = model(tokens)  # [batch_size, seq_len, tagset_size]
            _, preds = torch.max(outputs, dim=2)  # [batch_size, seq_len]

            preds = preds.cpu().numpy()
            tags = tags.cpu().numpy()

            for pred, tag, length in zip(preds, tags, batch['length']):
                pred = pred[:length].tolist()
                tag = tag[:length].tolist()
                pred = [idx2tag[p] for p in pred]
                tag = [idx2tag[t] for t in tag]
                all_preds.append(pred)
                all_tags.append(tag)

    return all_preds, all_tags
# Out:
# <ipython-input-22-7dae82388c73>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_filename)

# %%
# Get predictions on validation set
valid_preds, valid_tags = predict(model, valid_loader, device)

# Calculate F1 score
valid_f1 = f1_score(valid_tags, valid_preds)

# filtered_valid_pairs = [(y_pred, y_true) for pred, true in zip(valid_preds, valid_tags) for y_pred, y_true in zip(pred, true) if y_true != 'O']
# valid_accuracy = np.mean([y_pred == y_true for y_pred, y_true in filtered_valid_pairs]) if filtered_valid_pairs else 0.0

print(seq_classification_report(valid_tags, valid_preds))
print(f"Validation F1 Score: {valid_f1:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#          LOC       0.86      0.86      0.86      1837
#         MISC       0.76      0.79      0.78       919
#          ORG       0.85      0.71      0.77      1341
#          PER       0.83      0.85      0.84      1802
#
#    micro avg       0.83      0.81      0.82      5899
#    macro avg       0.83      0.80      0.81      5899
# weighted avg       0.83      0.81      0.82      5899
#
# Validation F1 Score: 0.8220

# %%
# Get predictions on the test set
test_preds, test_tags = predict(model, test_loader, device)

# Calculate F1 score
test_f1 = f1_score(test_tags, test_preds)

print(seq_classification_report(test_tags, test_preds))
print(f"Test F1 Score: {test_f1:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#          LOC       0.82      0.78      0.80      1657
#         MISC       0.61      0.65      0.63       702
#          ORG       0.79      0.66      0.72      1660
#          PER       0.75      0.76      0.75      1590
#
#    micro avg       0.76      0.72      0.74      5609
#    macro avg       0.74      0.71      0.73      5609
# weighted avg       0.76      0.72      0.74      5609
#
# Test F1 Score: 0.7413

# %% [markdown]
# # 7. Missclassified Sample Analysis

# %%
# Extract misclassified entities
errors = []
for true_seq, pred_seq, tokens in zip(test_tags, test_preds, dataset['test']['tokens']):
    for true_label, pred_label, token in zip(true_seq, pred_seq, tokens):
        if true_label != pred_label and true_label != 'O':
            errors.append((token, true_label, pred_label))

print(f"Total Errors: {len(errors)}")
print("First 10 errors:")
print(errors[:10])
# Out:
# Total Errors: 1921
# First 10 errors:
# [('JAPAN', 'B-LOC', 'B-MISC'), ('CHINA', 'B-PER', 'O'), ('Nadim', 'B-PER', 'O'), ('Ladki', 'I-PER', 'O'), ('Emirates', 'I-LOC', 'O'), ('Uzbekistan', 'B-LOC', 'O'), ('Uzbekistan', 'B-LOC', 'O'), ('Hiroshige', 'B-PER', 'O'), ('Yanagimoto', 'I-PER', 'O'), ('Bitar', 'B-PER', 'B-LOC')]

# %%
# Convert errors to DataFrame for analysis
error_df = pd.DataFrame(errors, columns=['Token', 'True Label', 'Predicted Label'])
error_df.head()
# Out:
#       Token True Label Predicted Label
# 0     JAPAN      B-LOC          B-MISC
# 1     CHINA      B-PER               O
# 2     Nadim      B-PER               O
# 3     Ladki      I-PER               O
# 4  Emirates      I-LOC               O

# %%
# Count most common misclassifications
most_common_errors = error_df.groupby(['True Label', 'Predicted Label']).size().reset_index(name='Count')
most_common_errors = most_common_errors.sort_values(by='Count', ascending=False)
most_common_errors.head(10)
# Out:
#    True Label Predicted Label  Count
# 22      B-ORG               O    267
# 30      B-PER               O    201
# 7       B-LOC               O    187
# 56      I-PER               O    165
# 14     B-MISC               O    155
# 50      I-ORG               O    108
# 17      B-ORG           B-PER     94
# 15      B-ORG           B-LOC     79
# 1       B-LOC           B-ORG     73
# 42     I-MISC               O     50

# %%
# Count misclassifications per NER class
error_counts = error_df['True Label'].value_counts().reset_index()
error_counts.columns = ['NER Class', 'Misclassification Count']

# Map label indices to names if necessary
label_map = {
    '0': 'O',
    '1': 'B-PER',
    '2': 'I-PER',
    '3': 'B-ORG',
    '4': 'I-ORG',
    '5': 'B-LOC',
    '6': 'I-LOC',
    '7': 'B-MISC',
    '8': 'I-MISC',
}

# Count misclassifications per NER class
error_counts = error_df['True Label'].value_counts().reset_index()
error_counts.columns = ['NER Class', 'Misclassification Count']

error_counts
# Out:
#   NER Class  Misclassification Count
# 0     B-ORG                      527
# 1     B-LOC                      344
# 2     B-PER                      290
# 3     I-ORG                      212
# 4    B-MISC                      206
# 5     I-PER                      194
# 6    I-MISC                       78
# 7     I-LOC                       70

# %%
# Analyze class imbalance in training data
all_labels = np.concatenate(dataset['train']['ner_tags'])
label_counts = Counter(all_labels)

# Map label indices to names
ner_label_map = {0: 'O', 1: 'B-PER', 2: 'I-PER', 3: 'B-ORG', 4: 'I-ORG', 5: 'B-LOC', 6: 'I-LOC', 7: 'B-MISC', 8: 'I-MISC'}
train_label_counts = {ner_label_map[key]: value for key, value in label_counts.items()}

# Convert to DataFrame
train_label_df = pd.DataFrame(list(train_label_counts.items()), columns=['NER Class', 'Count'])
train_label_df = train_label_df.sort_values(by='Count', ascending=False)

# Calculate percentage
train_label_df['Percentage'] = (train_label_df['Count'] / train_label_df['Count'].sum() * 100).round(1)

print(train_label_df)
# Out:
#   NER Class   Count  Percentage
# 1         O  169578        83.3
# 5     B-LOC    7140         3.5
# 3     B-PER    6600         3.2
# 0     B-ORG    6321         3.1
# 4     I-PER    4528         2.2
# 6     I-ORG    3704         1.8
# 2    B-MISC    3438         1.7
# 8     I-LOC    1157         0.6
# 7    I-MISC    1155         0.6

# %%
# Visualize misclassification distribution
plt.figure(figsize=(8,6))
sns.barplot(x='NER Class', y='Misclassification Count', data=error_counts)
plt.title('Misclassification Count per NER Class')
plt.show()
